# %%
import pandas as pd
from datetime import datetime

# %%
def send_product_report(file_path):
    df = pd.read_csv(file_path, 
                 encoding='windows-1251', sep=';')  
    
    df = df.rename(columns={'Номер': 'number', 
                   'Дата создания': 'create_date', 
                   'Дата оплаты': 'payment_date', 
                   'Title': 'tittle', 
                   'Статус': 'status',
                   'Заработано': 'money', 
                   'Город': 'city', 
                   'Платежная система': 'payment_system'})    
    
    all_money = df.money.sum()
    
    money_title = df \
        .query("status == 'Завершен'") \
        .groupby(['tittle'], as_index=False) \
        .aggregate({'money': 'sum', 'number': 'count'}) \
        .sort_values('money', ascending=False) \
        .rename(columns={'number': 'success_orders'})    
    
    today_day = datetime.today().strftime('%Y-%m-%d')
    file_name = 'money_title_{}.csv'
    file_name = file_name.format(today_day)    
    
    if int(money_title.money.sum()) == int(all_money):
        print('OK! File {} is written.'.format(file_name))
        money_title.to_csv(file_name, index=False)
    else:
        print('ERROR!')  
        
    return money_title

# %%
file_path = 'lesson_1_data.csv'

# %%
df = send_product_report(file_path)
# Out:
# OK! File money_title_2020-12-09.csv is written.

# %%
def cellsi(far):
    celsss = []
    for i in range(len(far)):
        celsss.append((far[i]-32)*5/9)
    return celsss

# %%
[50, 40, 37, 33]-[32]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-592f880fd847> in <module>
# ----> 1 [50, 40, 37, 33]-[32]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
cells = cellsi([50, 40, 37, 33])

# %%
pd.DataFrame(cells[:5], columns = ['temp']).temp.values.round(3)
# Out:
# array([10.   ,  4.444,  2.778,  0.556])

# %%
pd.DataFrame(cells)
# Out:
#            0
# 0  10.000000
# 1   4.444444
# 2   2.777778
# 3   0.555556

# %%
df = pd.read_csv('lesson_1_data.csv', 
                 encoding='windows-1251', sep=';')

# %%
df.tail()
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 287  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен     2935.44
# 288                        Курс обучения «Консультант»   Отменен        0.00
# 289                        Курс обучения «Консультант»  Завершен     7423.92
# 290  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен     2935.44
# 291  Курс от Школы Диетологов. Повышение квалификац...  Завершен     9898.56
#
#                   Город                 Платежная система
# 287   Самарская область                      Яндекс.Касса
# 288                 NaN                               NaN
# ...

# %%
df.shape
# Out:
# (292, 8)

# %%
df.dtypes
# Out:
# Номер                  int64
# Дата создания         object
# Дата оплаты           object
# Title                 object
# Статус                object
# Заработано           float64
# Город                 object
# Платежная система     object
# dtype: object

# %%
df.describe()
# Out:
#               Номер    Заработано
# count  2.920000e+02    292.000000
# mean   1.063745e+06   3397.615034
# std    4.438688e+02   5771.572829
# min    1.062823e+06      0.000000
# 25%    1.063608e+06      0.000000
# 50%    1.063698e+06   2935.440000
# 75%    1.063807e+06   2935.440000
# max    1.064796e+06  42750.000000

# %%
df.columns
# Out:
# Index(['Номер', 'Дата создания', 'Дата оплаты', 'Title', 'Статус',
#        'Заработано', 'Город', 'Платежная система'],
#       dtype='object')

# %%
df = df.rename(columns={'Номер': 'number', 
               'Дата создания': 'create_date', 
               'Дата оплаты': 'payment_date', 
               'Title': 'tittle', 
               'Статус': 'status',
               'Заработано': 'money', 
               'Город': 'city', 
               'Платежная система': 'payment_system'})

# %%
df.tail()
# Out:
#       number       create_date      payment_date  \
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                 tittle    status    money  \
# 287  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен  2935.44
# 288                        Курс обучения «Консультант»   Отменен     0.00
# 289                        Курс обучения «Консультант»  Завершен  7423.92
# 290  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен  2935.44
# 291  Курс от Школы Диетологов. Повышение квалификац...  Завершен  9898.56
#
#                    city                    payment_system
# 287   Самарская область                      Яндекс.Касса
# 288                 NaN                               NaN
# ...

# %%
df[['tittle', 'status']].head()
# Out:
#                         tittle    status
# 0      Курс обучения «Эксперт»  Завершен
# 1      Курс обучения «Эксперт»  Завершен
# 2   Курс обучения «Специалист»   Отменен
# 3  Курс обучения «Консультант»   Отменен
# 4      Курс обучения «Эксперт»   Отменен

# %%
all_money = df.money.sum()

# %%
all_money
# Out:
# 992103.5900000001

# %%
money_by_city = df \
    .groupby(['tittle', 'city'], as_index=False) \
    .aggregate({'money': 'sum'}) \
    .sort_values('money', ascending=False)

# %%
money_by_city.to_csv('money_by_city.csv', index=False)

# %%
money_title = df \
    .query("status == 'Завершен'") \
    .groupby(['tittle'], as_index=False) \
    .aggregate({'money': 'sum', 'number': 'count'}) \
    .sort_values('money', ascending=False) \
    .rename(columns={'number': 'success_orders'})

# %%
today_day = datetime.today().strftime('%Y-%m-%d')
file_name = 'money_title_{}.csv'
file_name = file_name.format(today_day)

# %%
if int(money_title.money.sum()) == int(all_money):
    print('OK! File {} is written.'.format(file_name))
    money_title.to_csv(file_name, index=False)
else:
    print('ERROR!')
# Out:
# OK! File money_title_2020-05-17.csv is written.

# %%
df.head()
# Out:
#     number       create_date      payment_date                       tittle  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52      Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27      Курс обучения «Эксперт»
# 2  1062856  01.12.2019 21:43               NaN   Курс обучения «Специалист»
# 3  1062880   03.12.2019 0:18               NaN  Курс обучения «Консультант»
# 4  1062899  03.12.2019 21:43               NaN      Курс обучения «Эксперт»
#
#      status    money                           city      payment_system
# 0  Завершен  29597.5                           Чита  Сбербанк эквайринг
# 1  Завершен  17450.3                      Краснодар        Яндекс.Касса
# 2   Отменен      0.0                            NaN                 NaN
# 3   Отменен      0.0  г.Москва и Московская область                 NaN
# 4   Отменен      0.0  г.Москва и Московская область                 NaN

# %%
df \
    .query('tittle == "Курс обучения «Консультант»"') \
    .groupby(['tittle', 'city'], as_index = False) \
    .aggregate({'money':'sum' , 'number': 'mean'})
# Out:
#                          tittle                                         city  \
# 0   Курс обучения «Консультант»                                     Massagno
# 1   Курс обучения «Консультант»                             Брянская область
# 2   Курс обучения «Консультант»                         Владимирская область
# 3   Курс обучения «Консультант»                        Волгоградская область
# 4   Курс обучения «Консультант»                          Вологодская область
# 5   Курс обучения «Консультант»                          Воронежская область
# 6   Курс обучения «Консультант»                      Калининградская область
# 7   Курс обучения «Консультант»                          Кемеровская область
# 8   Курс обучения «Консультант»                           Краснодарский край
# 9   Курс обучения «Консультант»                                       Кунгур
# 10  Курс обучения «Консультант»                           Курганская область
# ...

# %%
df.pivot_table(df[['']])

# %% [markdown]
# # ДЗ

# %%
df = pd.read_csv('2_taxi_nyc.csv', sep = ',')

# %%
len(df)
# Out:
# 29101

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pickup_dt     29101 non-null  object
#  1   pickup_month  29101 non-null  object
#  2   borough       26058 non-null  object
#  3   pickups       29101 non-null  int64
#  4   hday          29101 non-null  object
#  5   spd           29101 non-null  float64
#  6   vsb           29101 non-null  float64
#  7   temp          29101 non-null  float64
#  8   dewp          29101 non-null  float64
#  9   slp           29101 non-null  float64
#  10  pcp 01        29101 non-null  float64
#  11  pcp 06        29101 non-null  float64
#  12  pcp 24        29101 non-null  float64
#  13  sd            29101 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df.rename(columns={'pcp 01': 'pcp_01', 'pcp 06': 'pcp_06','pcp 24': 'pcp_24'})
# Out:
#                  pickup_dt pickup_month        borough  pickups hday  spd  \
# 0      2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0
# 1      2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0
# 2      2015-01-01 01:00:00          Jan            EWR        0    Y  5.0
# 3      2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0
# 4      2015-01-01 01:00:00          Jan         Queens      405    Y  5.0
# ...                    ...          ...            ...      ...  ...  ...
# 29096  2015-06-30 23:00:00          Jun            EWR        0    N  7.0
# 29097  2015-06-30 23:00:00          Jun      Manhattan     3828    N  7.0
# 29098  2015-06-30 23:00:00          Jun         Queens      580    N  7.0
# 29099  2015-06-30 23:00:00          Jun  Staten Island        0    N  7.0
# 29100  2015-06-30 23:00:00          Jun            NaN        3    N  7.0
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
df
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 0                              Курс обучения «Эксперт»  Завершен    29597.50
# 1                              Курс обучения «Эксперт»  Завершен    17450.30
# 2                           Курс обучения «Специалист»   Отменен        0.00
# ...

# %%
df['borough'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'borough'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c14764788632> in <module>
# ...

# %%
df.pickups.sum()
# Out:
# 14265773

# %%
df_2 = df.groupby('borough', as_index = False).agg({'pickups':'sum'})

# %%
df_2
# Out:
#          borough   pickups
# 0          Bronx    220047
# 1       Brooklyn   2321035
# 2            EWR       105
# 3      Manhattan  10367841
# 4         Queens   1343528
# 5  Staten Island      6957

# %%
df_2['borough'][df_2.pickups.idxmin()]
# Out:
# 'EWR'

# %%
df.groupby(['pickup_month', 'borough'], as_index = False) \
    .agg({'pickups':'sum'}) \
    .sort_values(['pickups'] , ascending = False) \
# Out:
#    pickup_month        borough  pickups
# 21          Jun      Manhattan  1995388
# 33          May      Manhattan  1888800
# 9           Feb      Manhattan  1718571
# 27          Mar      Manhattan  1661261
# 3           Apr      Manhattan  1648278
# 15          Jan      Manhattan  1455543
# 19          Jun       Brooklyn   482466
# 31          May       Brooklyn   476087
# 1           Apr       Brooklyn   378095
# 25          Mar       Brooklyn   346726
# 7           Feb       Brooklyn   328650
# 13          Jan       Brooklyn   309011
# 22          Jun         Queens   286311
# 34          May         Queens   275893
# 28          Mar         Queens   219561
# 4           Apr         Queens   216857
# 10          Feb         Queens   185695
# 16          Jan         Queens   159211
# 30          May          Bronx    53037
# 18          Jun          Bronx    49006
# 0           Apr          Bronx    34617
# 24          Mar          Bronx    32232
# ...
